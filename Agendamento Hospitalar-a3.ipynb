# %% [markdown]
# Caderno de exploracao dos dados do datasus 2008 pra frente

# %% [markdown]
# # Aula 1

# %%
import pandas as pd

# %%
dados = pd.read_csv("/content/A160324189_28_143_208.txt", encoding="ISO-8859-1", 
                    skiprows = 3, sep=";", skipfooter=12,
                    thousands=".", decimal=",")
dados.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   This is separate from the ipykernel package so we can avoid doing imports until
#   Unidade da Federação 1992/Mar  ...     2020/Ago         Total
# 0          11 Rondônia        -  ...   3556381.57  9.291297e+08
# 1              12 Acre        -  ...            -  4.206680e+08
# 2          13 Amazonas        -  ...   4726485.73  1.771655e+09
# 3           14 Roraima        -  ...   1524478.04  3.050109e+08
# 4              15 Pará        -  ...  11559714.54  4.437116e+09
#
# [5 rows x 280 columns]

# %%
dados.tail()
# Out:
#      Unidade da Federação 1992/Mar  ...     2020/Ago         Total
# 22   43 Rio Grande do Sul        -  ...  28349257.38  1.195865e+10
# 23  50 Mato Grosso do Sul        -  ...   4059220.22  2.172158e+09
# 24         51 Mato Grosso        -  ...   6174224.99  2.036924e+09
# 25               52 Goiás        -  ...  20242641.73  4.657349e+09
# 26    53 Distrito Federal        -  ...  12044848.02  2.429933e+09
#
# [5 rows x 280 columns]

# %%
dados.mean()
# Out:
# 2007/Ago    3.049528e+05
# 2007/Set    7.881453e+05
# 2007/Out    2.440163e+06
# 2007/Nov    5.517354e+06
# 2007/Dez    1.233716e+07
#                 ...
# 2020/Abr    4.000568e+07
# 2020/Mai    4.676903e+07
# 2020/Jun    4.536735e+07
# 2020/Jul    4.071708e+07
# Total       5.993724e+09
# Length: 157, dtype: float64

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 280 entries, Unidade da Federação to Total
# dtypes: float64(157), object(123)
# memory usage: 59.2+ KB

# %%
pd.options.display.float_format = "{:.2f}".format

# %%
dados.mean()
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2020/Abr     40005678.92
# 2020/Mai     46769027.82
# 2020/Jun     45367349.74
# 2020/Jul     40717083.95
# Total      5993724452.01
# Length: 157, dtype: float64

# %%
dados["2008/Ago"]
# Out:
# 0      2938286.29
# 1      1886871.84
# 2      8331763.97
# 3      1045291.11
# 4     23259148.28
# 5      1550340.63
# 6      5213290.38
# 7     14609872.57
# 8     10645917.52
# 9     29304821.51
# 10    10812840.19
# 11    12673774.35
# 12    31705296.79
# 13     9262767.68
# 14     4543252.50
# 15    43254543.33
# 16    80374117.08
# 17    12384068.19
# 18    42487939.51
# 19   179898070.22
# 20    56699001.13
# 21    28887854.62
# 22    56233758.74
# 23     9602843.49
# 24     8987811.95
# 25    21041071.33
# 26    11548451.89
# Name: 2008/Ago, dtype: float64

# %%
dados["2008/Ago"].mean()
# Out:
# 26636409.892222222

# %%
dados.plot(x="Unidade da Federação", y="2008/Ago")

# %%
dados.plot(x="Unidade da Federação", y="2008/Ago", kind="bar", figsize=(9,6))

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

ax = dados.plot(x="Unidade da Federação", y="2008/Ago", kind="bar", figsize=(9,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))

plt.title("Valor por unidade da federação")
plt.show()

# %% [markdown]
# # Desafio: escolher um título mais descritivo, que passe a  mensagem adequada.

# %%
ax = dados.plot(x="Unidade da Federação", y="2008/Ago", kind="bar", figsize=(9,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.title("Gastos de internação ref. ao mês de Processamente")
plt.show()

# %% [markdown]
# # Desafio: faça a mesma análise pro mês mais recente.

# %%
dados["2020/Ago"][1] = 0.0
dados["2020/Ago"] = dados["2020/Ago"].astype(float)
ax = dados.plot(x="Unidade da Federação", y="2020/Ago", kind="bar", figsize=(9,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.title("Gastos de internação ref. ao mês de Processamente")
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# # Aula 2

# %%
dados[["2008/Ago", "2008/Set"]].head()
# Out:
#      2008/Ago    2008/Set
# 0  2938286.29  2843930.91
# 1  1886871.84  2084884.80
# 2  8331763.97  8148089.92
# 3  1045291.11  1003740.89
# 4 23259148.28 23667690.01

# %%
dados.mean()
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2020/Mai     46769027.82
# 2020/Jun     45367349.74
# 2020/Jul     40717083.95
# 2020/Ago     19144523.30
# Total      5993724452.01
# Length: 158, dtype: float64

# %%
colunas_usaveis = dados.mean().index.tolist()
colunas_usaveis.insert(0, "Unidade da Federação")
colunas_usaveis
# Out:
# ['Unidade da Federação',
#  '2007/Ago',
#  '2007/Set',
#  '2007/Out',
#  '2007/Nov',
#  '2007/Dez',
#  '2008/Jan',
#  '2008/Fev',
#  '2008/Mar',
#  '2008/Abr',
#  '2008/Mai',
#  '2008/Jun',
#  '2008/Jul',
#  '2008/Ago',
#  '2008/Set',
#  '2008/Out',
#  '2008/Nov',
#  '2008/Dez',
#  '2009/Jan',
#  '2009/Fev',
#  '2009/Mar',
#  '2009/Abr',
#  '2009/Mai',
#  '2009/Jun',
#  '2009/Jul',
#  '2009/Ago',
#  '2009/Set',
#  '2009/Out',
#  '2009/Nov',
#  '2009/Dez',
#  '2010/Jan',
#  '2010/Fev',
#  '2010/Mar',
#  '2010/Abr',
#  '2010/Mai',
#  '2010/Jun',
#  '2010/Jul',
#  '2010/Ago',
#  '2010/Set',
#  '2010/Out',
#  '2010/Nov',
#  '2010/Dez',
#  '2011/Jan',
#  '2011/Fev',
#  '2011/Mar',
#  '2011/Abr',
#  '2011/Mai',
#  '2011/Jun',
#  '2011/Jul',
#  '2011/Ago',
#  '2011/Set',
#  '2011/Out',
#  '2011/Nov',
#  '2011/Dez',
#  '2012/Jan',
#  '2012/Fev',
#  '2012/Mar',
#  '2012/Abr',
#  '2012/Mai',
#  '2012/Jun',
#  '2012/Jul',
#  '2012/Ago',
#  '2012/Set',
#  '2012/Out',
#  '2012/Nov',
#  '2012/Dez',
#  '2013/Jan',
#  '2013/Fev',
#  '2013/Mar',
#  '2013/Abr',
#  '2013/Mai',
#  '2013/Jun',
#  '2013/Jul',
#  '2013/Ago',
#  '2013/Set',
#  '2013/Out',
#  '2013/Nov',
#  '2013/Dez',
#  '2014/Jan',
#  '2014/Fev',
#  '2014/Mar',
#  '2014/Abr',
#  '2014/Mai',
#  '2014/Jun',
#  '2014/Jul',
#  '2014/Ago',
#  '2014/Set',
#  '2014/Out',
#  '2014/Nov',
#  '2014/Dez',
#  '2015/Jan',
#  '2015/Fev',
#  '2015/Mar',
#  '2015/Abr',
#  '2015/Mai',
#  '2015/Jun',
#  '2015/Jul',
#  '2015/Ago',
#  '2015/Set',
#  '2015/Out',
#  '2015/Nov',
#  '2015/Dez',
#  '2016/Jan',
#  '2016/Fev',
#  '2016/Mar',
#  '2016/Abr',
#  '2016/Mai',
#  '2016/Jun',
#  '2016/Jul',
#  '2016/Ago',
#  '2016/Set',
#  '2016/Out',
#  '2016/Nov',
#  '2016/Dez',
#  '2017/Jan',
#  '2017/Fev',
#  '2017/Mar',
#  '2017/Abr',
#  '2017/Mai',
#  '2017/Jun',
#  '2017/Jul',
#  '2017/Ago',
#  '2017/Set',
#  '2017/Out',
#  '2017/Nov',
#  '2017/Dez',
#  '2018/Jan',
#  '2018/Fev',
#  '2018/Mar',
#  '2018/Abr',
#  '2018/Mai',
#  '2018/Jun',
#  '2018/Jul',
#  '2018/Ago',
#  '2018/Set',
#  '2018/Out',
#  '2018/Nov',
#  '2018/Dez',
#  '2019/Jan',
#  '2019/Fev',
#  '2019/Mar',
#  '2019/Abr',
#  '2019/Mai',
#  '2019/Jun',
#  '2019/Jul',
#  '2019/Ago',
#  '2019/Set',
#  '2019/Out',
#  '2019/Nov',
#  '2019/Dez',
#  '2020/Jan',
#  '2020/Fev',
#  '2020/Mar',
#  '2020/Abr',
#  '2020/Mai',
#  '2020/Jun',
#  '2020/Jul',
#  '2020/Ago',
#  'Total']

# %%
usaveis = dados[colunas_usaveis]
usaveis.head()
# Out:
#   Unidade da Federação  2007/Ago  ...    2020/Ago         Total
# 0          11 Rondônia   4209.37  ...  3556381.57  929129659.72
# 1              12 Acre  10470.07  ...        0.00  420668039.63
# 2          13 Amazonas  35752.72  ...  4726485.73 1771654871.23
# 3           14 Roraima   4785.91  ...  1524478.04  305010883.18
# 4              15 Pará 181159.29  ... 11559714.54 4437115730.71
#
# [5 rows x 159 columns]

# %%
usaveis = usaveis.set_index("Unidade da Federação")
usaveis
# Out:
#                          2007/Ago   2007/Set  ...     2020/Ago          Total
# Unidade da Federação                          ...
# 11 Rondônia               4209.37   16397.03  ...   3556381.57   929129659.72
# 12 Acre                  10470.07   14001.71  ...         0.00   420668039.63
# 13 Amazonas              35752.72   45570.64  ...   4726485.73  1771654871.23
# 14 Roraima                4785.91   11858.63  ...   1524478.04   305010883.18
# 15 Pará                 181159.29  433414.74  ...  11559714.54  4437115730.71
# 16 Amapá                 33672.74  104822.98  ...    834187.31   291637984.75
# 17 Tocantins              4113.76   76633.06  ...   2453362.74   999998621.85
# 21 Maranhão             385330.18 1018352.93  ...  10916718.78  3632860959.84
# 22 Piauí                220788.25  353468.67  ...   7926321.69  2130616492.35
# 23 Ceará                357904.65  572356.18  ...  14559529.59  6197357245.98
# 24 Rio Grande do Norte  134605.36  272088.08  ...   8080160.97  2477372149.60
# 25 Paraíba               97352.78  368130.43  ...   8585226.08  2470550104.25
# 26 Pernambuco           400640.85 1088340.42  ...  33544876.14  8046954289.39
# 27 Alagoas              104243.75  174024.90  ...   6487947.82  2104405303.11
# 28 Sergipe               27453.63   78565.19  ...   1742127.72  1130337049.71
# 29 Bahia                135146.36  448349.75  ...  26023558.53  9193802684.16
# 31 Minas Gerais         971394.37 2861781.50  ...  57473699.06 19160106499.88
# 32 Espírito Santo        57408.11  284224.80  ...  10824255.26  3139189177.73
# 33 Rio de Janeiro       469469.34  921646.57  ...  36264322.65  9696362872.68
# 35 São Paulo           1665349.90 4434168.64  ... 140414944.95 38929353900.57
# 41 Paraná               554800.22 1431708.01  ...  41542401.16 13786964617.27
# 42 Santa Catarina       693955.05 1092964.12  ...  16991236.43  7324100054.96
# 43 Rio Grande do Sul   1049252.33 3182913.14  ...  28349257.38 11958647088.33
# 50 Mato Grosso do Sul   199556.12  573675.41  ...   4059220.22  2172157981.36
# 51 Mato Grosso           63562.50  232444.62  ...   6174224.99  2036923784.59
# 52 Goiás                179395.82  418053.58  ...  20242641.73  4657348958.66
# 53 Distrito Federal     191951.47  769966.25  ...  12044848.02  2429933198.76
#
# [27 rows x 158 columns]

# %%
usaveis["2019/Ago"].head()
# Out:
# Unidade da Federação
# 11 Rondônia    8909111.89
# 12 Acre        2981072.98
# 13 Amazonas   16493719.52
# 14 Roraima     3181321.82
# 15 Pará       36462011.47
# Name: 2019/Ago, dtype: float64

# %%
usaveis.loc["12 Acre"]
# Out:
# 2007/Ago       10470.07
# 2007/Set       14001.71
# 2007/Out       86200.85
# 2007/Nov      301323.68
# 2007/Dez      769612.36
#                ...
# 2020/Mai     2383895.48
# 2020/Jun     2199920.70
# 2020/Jul     1163813.08
# 2020/Ago           0.00
# Total      420668039.63
# Name: 12 Acre, Length: 158, dtype: float64

# %%
usaveis.plot(figsize=(12,6))

# %%
usaveis.T.head()
# Out:
# Unidade da Federação  11 Rondônia   12 Acre  ...   52 Goiás  53 Distrito Federal
# 2007/Ago                  4209.37  10470.07  ...  179395.82            191951.47
# 2007/Set                 16397.03  14001.71  ...  418053.58            769966.25
# 2007/Out                133645.19  86200.85  ... 1198730.25           2165619.56
# 2007/Nov                346912.84 301323.68  ... 2712117.54           3813256.48
# 2007/Dez                711758.31 769612.36  ... 9293914.78           7121965.42
#
# [5 rows x 27 columns]

# %%
usaveis.T.tail()
# Out:
# Unidade da Federação  11 Rondônia  ...  53 Distrito Federal
# 2020/Mai               8581195.13  ...          21437430.22
# 2020/Jun               9193593.76  ...          23479773.03
# 2020/Jul               7407388.24  ...          22233542.26
# 2020/Ago               3556381.57  ...          12044848.02
# Total                929129659.72  ...        2429933198.76
#
# [5 rows x 27 columns]

# %%
usaveis.T.plot(figsize=(10,6))

# %%
usaveis = usaveis.drop("Total", axis=1)
usaveis.head()
# Out:
#                       2007/Ago  2007/Set  ...    2020/Jul    2020/Ago
# Unidade da Federação                      ...
# 11 Rondônia            4209.37  16397.03  ...  7407388.24  3556381.57
# 12 Acre               10470.07  14001.71  ...  1163813.08        0.00
# 13 Amazonas           35752.72  45570.64  ... 13358514.02  4726485.73
# 14 Roraima             4785.91  11858.63  ...  2739498.41  1524478.04
# 15 Pará              181159.29 433414.74  ... 27618727.51 11559714.54
#
# [5 rows x 157 columns]

# %%
usaveis.T.plot(figsize=(10,6))

# %% [markdown]
# # Desafio: reposicionar a legenda. Dentro? Fora? Onde?

# %%
ax = usaveis.T.plot(figsize=(12,6))
ax.legend(bbox_to_anchor=(1,1),ncol=3,loc='upper right')
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.title("Gastos de internação ref. ao mês de Processamente")
plt.show()

# %% [markdown]
# # Desafio: mudar palete de cores com o matplotlib

# %%
import matplotlib.cm as cm

ax = usaveis.T.plot(figsize=(12,6))
ax.legend(bbox_to_anchor=(1,1),ncol=3,loc='upper right')
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.title("Gastos de internação ref. ao mês de Processamente")
plt.set_cmap(cm.jet)
plt.show()

# %% [markdown]
# # Aula 3

# %%
usaveis.head()
# Out:
#                       2007/Ago  2007/Set  ...    2020/Jul    2020/Ago
# Unidade da Federação                      ...
# 11 Rondônia            4209.37  16397.03  ...  7407388.24  3556381.57
# 12 Acre               10470.07  14001.71  ...  1163813.08        0.00
# 13 Amazonas           35752.72  45570.64  ... 13358514.02  4726485.73
# 14 Roraima             4785.91  11858.63  ...  2739498.41  1524478.04
# 15 Pará              181159.29 433414.74  ... 27618727.51 11559714.54
#
# [5 rows x 157 columns]

# %%
usaveis.T.columns
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará',
#        '16 Amapá', '17 Tocantins', '21 Maranhão', '22 Piauí', '23 Ceará',
#        '24 Rio Grande do Norte', '25 Paraíba', '26 Pernambuco', '27 Alagoas',
#        '28 Sergipe', '29 Bahia', '31 Minas Gerais', '32 Espírito Santo',
#        '33 Rio de Janeiro', '35 São Paulo', '41 Paraná', '42 Santa Catarina',
#        '43 Rio Grande do Sul', '50 Mato Grosso do Sul', '51 Mato Grosso',
#        '52 Goiás', '53 Distrito Federal'],
#       dtype='object', name='Unidade da Federação')

# %%
usaveis.T.columns[:5]
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará'], dtype='object', name='Unidade da Federação')

# %%
usaveis.index[:5]
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará'], dtype='object', name='Unidade da Federação')

# %%
usaveis[:5]
# Out:
#                       2007/Ago  2007/Set  ...    2020/Jul    2020/Ago
# Unidade da Federação                      ...
# 11 Rondônia            4209.37  16397.03  ...  7407388.24  3556381.57
# 12 Acre               10470.07  14001.71  ...  1163813.08        0.00
# 13 Amazonas           35752.72  45570.64  ... 13358514.02  4726485.73
# 14 Roraima             4785.91  11858.63  ...  2739498.41  1524478.04
# 15 Pará              181159.29 433414.74  ... 27618727.51 11559714.54
#
# [5 rows x 157 columns]

# %%
usaveis[:7].T.plot(figsize=(10,6))

# %%
import numpy as np
np.random.seed(687942)

usaveis.sample(n=7)
# Out:
#                         2007/Ago   2007/Set  ...     2020/Jul    2020/Ago
# Unidade da Federação                         ...
# 32 Espírito Santo       57408.11  284224.80  ...  27460475.47 10824255.26
# 31 Minas Gerais        971394.37 2861781.50  ... 120467187.34 57473699.06
# 24 Rio Grande do Norte 134605.36  272088.08  ...  19593057.45  8080160.97
# 17 Tocantins             4113.76   76633.06  ...   4489665.87  2453362.74
# 53 Distrito Federal    191951.47  769966.25  ...  22233542.26 12044848.02
# 50 Mato Grosso do Sul  199556.12  573675.41  ...  12508717.35  4059220.22
# 16 Amapá                33672.74  104822.98  ...   2155083.37   834187.31
#
# [7 rows x 157 columns]

# %%
usaveis.sample(7)
# Out:
#                        2007/Ago   2007/Set  ...     2020/Jul     2020/Ago
# Unidade da Federação                        ...
# 42 Santa Catarina     693955.05 1092964.12  ...  51764534.76  16991236.43
# 33 Rio de Janeiro     469469.34  921646.57  ...  71540227.33  36264322.65
# 31 Minas Gerais       971394.37 2861781.50  ... 120467187.34  57473699.06
# 35 São Paulo         1665349.90 4434168.64  ... 282709570.31 140414944.95
# 21 Maranhão           385330.18 1018352.93  ...  24374205.15  10916718.78
# 52 Goiás              179395.82  418053.58  ...  33499284.38  20242641.73
# 32 Espírito Santo      57408.11  284224.80  ...  27460475.47  10824255.26
#
# [7 rows x 157 columns]

# %%
# ideia de como funciona aleatoriedade
# pseudo randomness

# seed = 6987
# random = seed / 10, seed = seed * 2 /3


# random ===> 698...... (seed=4658)
# random ==> 465 (seed = 310)
# random ==> 31

# %% [markdown]
# # Desafio: adicionar uma coluna mostrando a região de cada estado

# %%
estados = usaveis.index

regiao = {'1':'Norte',
          '2':'Nordeste',
          '3':'Sudeste',
          '4':'Sul',
          '5':'Centro-Oeste'}

col_regiao = []

for a in estados:
  col_regiao.append(regiao[a[0]])

usaveis.insert(0,'Região',col_regiao)

# %%
usaveis.head()
# Out:
#                      Região  2007/Ago  ...    2020/Jul    2020/Ago
# Unidade da Federação                   ...
# 11 Rondônia           Norte   4209.37  ...  7407388.24  3556381.57
# 12 Acre               Norte  10470.07  ...  1163813.08        0.00
# 13 Amazonas           Norte  35752.72  ... 13358514.02  4726485.73
# 14 Roraima            Norte   4785.91  ...  2739498.41  1524478.04
# 15 Pará               Norte 181159.29  ... 27618727.51 11559714.54
#
# [5 rows x 158 columns]

# %%
usaveis = usaveis.drop("Região", axis=1)

# %% [markdown]
# # Aula 3.1

# %%
usaveis["Total"] = usaveis.sum(axis=1) # [0,1,2] ["SP"]
usaveis.head()
# Out:
#                       2007/Ago  2007/Set  ...    2020/Ago         Total
# Unidade da Federação                      ...
# 11 Rondônia            4209.37  16397.03  ...  3556381.57  929129055.39
# 12 Acre               10470.07  14001.71  ...        0.00  420666755.81
# 13 Amazonas           35752.72  45570.64  ...  4726485.73 1771652039.82
# 14 Roraima             4785.91  11858.63  ...  1524478.04  305010469.49
# 15 Pará              181159.29 433414.74  ... 11559714.54 4437097195.11
#
# [5 rows x 158 columns]

# %%
ordenado_por_total = usaveis.sort_values("Total", ascending=False)
ordenado_por_total = ordenado_por_total.drop("Total", axis=1)
ordenado_por_total.head()
# Out:
#                        2007/Ago   2007/Set  ...     2020/Jul     2020/Ago
# Unidade da Federação                        ...
# 35 São Paulo         1665349.90 4434168.64  ... 282709570.31 140414944.95
# 31 Minas Gerais       971394.37 2861781.50  ... 120467187.34  57473699.06
# 41 Paraná             554800.22 1431708.01  ...  80320852.69  41542401.16
# 43 Rio Grande do Sul 1049252.33 3182913.14  ...  78929703.81  28349257.38
# 33 Rio de Janeiro     469469.34  921646.57  ...  71540227.33  36264322.65
#
# [5 rows x 157 columns]

# %% [markdown]
# # Desafio: deixar o gráfico mais bonito. A mensagem mais clara.

# %%
ax = ordenado_por_total.head(5).T.plot(figsize=(12,6))
ax.legend(bbox_to_anchor=(1,.5),ncol=1,loc='upper left')
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.title("Gastos de internação do Sus - Estados que mais gastaram")
plt.set_cmap(cm.jet)
plt.show()

# %% [markdown]
# #Desafio: adicione seu estado aos 5 estados existentes e plote
# Adicionando Pernambuco

# %%
Top5Estados=ordenado_por_total.index[:5].tolist()
Top5Estados.append('26 Pernambuco')

# %%
ax = ordenado_por_total.T[Top5Estados].plot(figsize=(12,6))
ax.legend(bbox_to_anchor=(1,.5),ncol=1,loc='upper left')
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}/"))
plt.title("Gastos de internação do Sus - Estados que mais gastaram")
plt.set_cmap(cm.jet)
plt.show()

# %% [markdown]
# # Aula 3.2

# %%
colunas_interessadas = ordenado_por_total.columns[6:]
ordenado_por_total = ordenado_por_total[colunas_interessadas]

# %%
ordenado_por_total.T.plot(figsize=(14,6))

# %% [markdown]
# # Desafio: googlar os casos de dengue no Brasil e se reflete nos gastos

# %%
ordenado_por_total.head(5)[['2012/Out','2012/Nov','2012/Dez','2013/Jan','2013/Fev','2013/Mar','2013/Abr']]
# Out:
#                          2012/Out     2012/Nov  ...     2013/Mar     2013/Abr
# Unidade da Federação                            ...
# 35 São Paulo         278819909.14 225775860.13  ... 254938242.41 262649865.82
# 31 Minas Gerais      122099210.56 112211647.27  ... 126117866.62 131252895.30
# 41 Paraná             84988531.01  78726146.77  ...  83934466.10  91658827.98
# 43 Rio Grande do Sul  77155562.05  69590896.90  ...  76562940.15  82705691.47
# 33 Rio de Janeiro     57949268.00  51632756.44  ...  57518964.22  63649897.51
#
# [5 rows x 7 columns]

# %% [markdown]
# Realmente ocorreu um aumento nos casos de dengue esse ano, quase triplicaram. Mas é dificil dizer se o aumento de gastos causou o aumento de gastos.
#
# http://g1.globo.com/bemestar/noticia/2013/02/casos-de-dengue-no-pais-aumentam-190-no-comeco-de-2013-diz-governo.html

# %% [markdown]
# #Desafio: plotar só os estados do sudeste e ver se afetou com um pico em 2012/2013 de forma similar esses estados

# %%
ax = ordenado_por_total.T[Top5Estados].plot(figsize=(12,6))
ax.legend(bbox_to_anchor=(1,.5),ncol=1,loc='upper left')
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.title("Gastos de internação do Sus - Estados que mais gastaram")
plt.set_cmap(cm.jet)
plt.show()

# %% [markdown]
# #Desafio: adicionar seu estado escolhido novamente e deixe o gráfico informativo com suas informações claras

# %%
ax = ordenado_por_total.T[Top5Estados].plot(figsize=(12,6))
ax.legend(bbox_to_anchor=(1,.5),ncol=1,loc='upper left')
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.title("Gastos de internação do Sus - Estados que mais gastaram")
plt.set_cmap(cm.jet)
plt.show()

# %% [markdown]
# # Aula 4

# %%
ordenado_por_total = ordenado_por_total/1000000 
ordenado_por_total.head(3).T.plot(figsize=(10,6))

# %%
meses_filtrados = ordenado_por_total.columns[47:150] 
ordenado_por_total[meses_filtrados].head(3).T.plot(figsize=(10,6))

# %%
ordenado_por_total[meses_filtrados].head(3).T.plot(figsize=(10,6))
plt.ylim(0, 350)
# Out:
# (0.0, 350.0)

# %%
ordenado_por_total[meses_filtrados].head(3).T.plot(figsize=(10,6))
plt.ylim(100, 350)
# Out:
# (100.0, 350.0)

# %%
ordenado_por_total[ordenado_por_total.columns[-12:]].head(3).T.plot(figsize=(10,6))
plt.ylim(0, 350)
# Out:
# (0.0, 350.0)

# %%
ordenado_por_total[ordenado_por_total.columns[-24:]].head(3).T.plot(figsize=(10,6))
plt.ylim(0, 350)
# Out:
# (0.0, 350.0)

# %%
ordenado_por_total[ordenado_por_total.columns[-60:]].head(3).T.plot(figsize=(10,6))
plt.ylim(0, 350)
# Out:
# (0.0, 350.0)

# %%
ordenado_por_total.head(5).T.plot(figsize=(10,6))
plt.ylim(0, 350)
# Out:
# (0.0, 350.0)

# %%
ordenado_por_total.head(5).T.plot(figsize=(6,6))

# %%
ordenado_por_total.head(5).T.plot(figsize=(20,6))

# %% [markdown]
# # Aulas 5

# %%
mes_mais_recente = ordenado_por_total.columns[-1]
mes_mais_recente
# Out:
# '2020/Ago'

# %%
gastos_do_mais_recente = ordenado_por_total[mes_mais_recente]
gastos_do_mais_recente.head()
# Out:
# Unidade da Federação
# 35 São Paulo           140.41
# 31 Minas Gerais         57.47
# 41 Paraná               41.54
# 43 Rio Grande do Sul    28.35
# 33 Rio de Janeiro       36.26
# Name: 2020/Ago, dtype: float64

# %%
gastos_do_mais_recente.plot()

# %%
gastos_do_mais_recente.plot(kind='pie')

# %% [markdown]
# Horrores da pizza:
#
# - legenda esta horrível
# - número de fatias inacreditável
#
# Já estamos com uma vantagem
# - o gráfico veio ordenado

# %%
gastos_do_mais_recente.sample(frac=1)
# Out:
# Unidade da Federação
# 28 Sergipe                 1.74
# 27 Alagoas                 6.49
# 43 Rio Grande do Sul      28.35
# 14 Roraima                 1.52
# 51 Mato Grosso             6.17
# 21 Maranhão               10.92
# 11 Rondônia                3.56
# 26 Pernambuco             33.54
# 15 Pará                   11.56
# 12 Acre                    0.00
# 52 Goiás                  20.24
# 13 Amazonas                4.73
# 50 Mato Grosso do Sul      4.06
# 31 Minas Gerais           57.47
# 16 Amapá                   0.83
# 33 Rio de Janeiro         36.26
# 25 Paraíba                 8.59
# 32 Espírito Santo         10.82
# 29 Bahia                  26.02
# 24 Rio Grande do Norte     8.08
# 17 Tocantins               2.45
# 42 Santa Catarina         16.99
# 35 São Paulo             140.41
# 53 Distrito Federal       12.04
# 22 Piauí                   7.93
# 41 Paraná                 41.54
# 23 Ceará                  14.56
# Name: 2020/Ago, dtype: float64

# %%
gastos_do_mais_recente.sample(frac=1).plot(kind='pie')

# %% [markdown]
# Horrores da pizza:
#
# - legenda esta horrível
# - número de fatias inacreditável
# - não da para saber a order
# - cores repetidas
# - muito ruim para definir ordem
# - péssimo para COMPARAR

# %%
# visualização pra valor absoluto

gastos_do_mais_recente
# Out:
# Unidade da Federação
# 35 São Paulo             140.41
# 31 Minas Gerais           57.47
# 41 Paraná                 41.54
# 43 Rio Grande do Sul      28.35
# 33 Rio de Janeiro         36.26
# 29 Bahia                  26.02
# 26 Pernambuco             33.54
# 42 Santa Catarina         16.99
# 23 Ceará                  14.56
# 52 Goiás                  20.24
# 15 Pará                   11.56
# 21 Maranhão               10.92
# 32 Espírito Santo         10.82
# 24 Rio Grande do Norte     8.08
# 25 Paraíba                 8.59
# 53 Distrito Federal       12.04
# 50 Mato Grosso do Sul      4.06
# 22 Piauí                   7.93
# 27 Alagoas                 6.49
# 51 Mato Grosso             6.17
# 13 Amazonas                4.73
# 28 Sergipe                 1.74
# 17 Tocantins               2.45
# 11 Rondônia                3.56
# 12 Acre                    0.00
# 14 Roraima                 1.52
# 16 Amapá                   0.83
# Name: 2020/Ago, dtype: float64

# %%
gastos_do_mais_recente / gastos_do_mais_recente.loc["33 Rio de Janeiro"]
# Out:
# Unidade da Federação
# 35 São Paulo             3.87
# 31 Minas Gerais          1.58
# 41 Paraná                1.15
# 43 Rio Grande do Sul     0.78
# 33 Rio de Janeiro        1.00
# 29 Bahia                 0.72
# 26 Pernambuco            0.93
# 42 Santa Catarina        0.47
# 23 Ceará                 0.40
# 52 Goiás                 0.56
# 15 Pará                  0.32
# 21 Maranhão              0.30
# 32 Espírito Santo        0.30
# 24 Rio Grande do Norte   0.22
# 25 Paraíba               0.24
# 53 Distrito Federal      0.33
# 50 Mato Grosso do Sul    0.11
# 22 Piauí                 0.22
# 27 Alagoas               0.18
# 51 Mato Grosso           0.17
# 13 Amazonas              0.13
# 28 Sergipe               0.05
# 17 Tocantins             0.07
# 11 Rondônia              0.10
# 12 Acre                  0.00
# 14 Roraima               0.04
# 16 Amapá                 0.02
# Name: 2020/Ago, dtype: float64

# %% [markdown]
# # Criar a tabela de comparação com seu estado ( ou estado de preferência)

# %%
(gastos_do_mais_recente / gastos_do_mais_recente.loc["33 Rio de Janeiro"]).head()
# Out:
# Unidade da Federação
# 35 São Paulo           3.87
# 31 Minas Gerais        1.58
# 41 Paraná              1.15
# 43 Rio Grande do Sul   0.78
# 33 Rio de Janeiro      1.00
# Name: 2020/Ago, dtype: float64

# %%
gastos_do_mais_recente.plot(kind = 'bar')

# %%
gastos_do_mais_recente = gastos_do_mais_recente.sort_values(ascending=False)
gastos_do_mais_recente.plot(kind = 'bar')

# %% [markdown]
# # Desafio: documentação do matplotlib e pandas para colocar grid no gráfico

# %%
gastos_do_mais_recente.plot(kind = 'bar').grid(axis='y')

# %% [markdown]
# # Desafio: gráfico de barra dos outros estados em função ao seu estado

# %% [markdown]
# # Desafio: gasto por população de dois estados, escolha dois estados, gráfico de barra

# %% [markdown]
# # Desafio: Explore e levante hipóteses e perguntas
