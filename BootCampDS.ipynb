# %% [markdown]
# <a href="https://colab.research.google.com/github/rabastos44/BootcampDS/blob/master/BootCampDS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Caderno de Analises DataSUS

# %%
import pandas as pd

# %%
# Clone the entire repo.
# !git clone -l -s git://github.com/rabastos44/BootcampDS.git BootcampDS
# %cd BootcampDS
# !ls
# Out:
# Cloning into 'BootcampDS'...
# ...
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 7 (delta 1), reused 3 (delta 0), pack-reused 0
# Receiving objects: 100% (7/7), 247.54 KiB | 10.76 MiB/s, done.
# Resolving deltas: 100% (1/1), done.
# /content/BootcampDS
# A151346189_28_143_208.txt  BootCampDS.ipynb  estimativa_dou_2020.xls

# %%
dados = pd.read_csv("/content/BootcampDS/A151346189_28_143_208.txt", encoding="iso-8859-1", sep=";" 
                    , skiprows=3 ,skipfooter=12, decimal=",")
dados.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   Unidade da Federação     2008/Jan  ...     2020/Ago         Total
# 0          11 Rondônia   1388528.39  ...  10285455.78  9.291297e+08
# 1              12 Acre    902416.00  ...            -  4.206680e+08
# 2          13 Amazonas   4735529.42  ...  14726443.67  1.771655e+09
# 3           14 Roraima    657889.53  ...   2826486.18  3.050109e+08
# 4              15 Pará  18864744.11  ...  39911193.02  4.437116e+09
#
# [5 rows x 154 columns]

# %%
dados.mean()
# Out:
# 2008/Jan    1.512685e+07
# 2008/Fev    2.271016e+07
# 2008/Mar    2.459419e+07
# 2008/Abr    2.543196e+07
# 2008/Mai    2.651125e+07
#                 ...
# 2020/Abr    4.101366e+07
# 2020/Mai    4.419363e+07
# 2020/Jun    4.732999e+07
# 2020/Jul    5.449551e+07
# Total       5.993732e+09
# Length: 151, dtype: float64

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
axis = dados.plot(x="Unidade da Federação", y="2020/Jun", kind="bar", figsize=(10,7))
axis.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}", useLocale="pt_br"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-8edcfdd91807> in <module>()
#       1 axis = dados.plot(x="Unidade da Federação", y="2020/Jun", kind="bar", figsize=(10,7))
# ----> 2 axis.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}", useLocale="pt_br"))
#
# TypeError: __init__() got an unexpected keyword argument 'useLocale'
