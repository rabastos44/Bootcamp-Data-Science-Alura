# %% [markdown]
# <a href="https://colab.research.google.com/github/rabastos44/Bootcamp-Data-Science-Alura/blob/master/Modulo3/Teorema_do_Limite_Central.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# O **Teorema do Limite Central** afirma que, com o aumento do tamanho da amostra, a distribuição das médias amostrais se aproxima de uma distribuição normal com média igual à média da população e desvio padrão igual ao desvio padrão da variável original dividido pela raiz quadrada do tamanho da amostra. Este fato é assegurado para $n$ maior ou igual a 30.
#
#
# .
# # $$\sigma_\bar{x} = \frac{\sigma}{\sqrt{n}}$$
# ​
# O desvio padrão das médias amostrais é conhecido como **erro padrão da média**

# %%
import pandas as pd
from zipfile import ZipFile



caminho = "/content/drive/MyDrive/módulo3/PeNSE_2015_AMOSTRA2 (1).zip"
zip = ZipFile(caminho)
caminho_pasta_zipada = zip.namelist()[1]

dados = pd.read_csv(zip.open(caminho_pasta_zipada), sep = ";", thousands = ".", decimal = ",")
dados.head()
# Out:
#    ANOPESQ  PAIS  REGEOGR  VB00004  VB01001  ...  V0008  V0041  aluno  escola  turma
# 0     2015    76        1        1        2  ...      4      1      1       1    296
# 1     2015    76        1        1        2  ...      4      1      2       1    296
# 2     2015    76        1        1        1  ...      4      1      3       1    296
# 3     2015    76        1        1        1  ...      4      1      4       1    296
# 4     2015    76        1        1        1  ...      4      1      5       1    296
#
# [5 rows x 181 columns]

# %%
dados["IMC"] = dados["VB17003"]/ ((dados["VB17004"]/100)**2)
dados["IMC"]
# Out:
# 0        15.051321
# 1        21.727839
# 2        18.502907
# 3        23.322831
# 4        28.122076
#            ...
# 16551    20.113223
# 16552    17.930782
# 16553    23.968489
# 16554    18.995343
# 16555    23.303246
# Name: IMC, Length: 16556, dtype: float64

# %%
n = 2000
total_de_amostras = 1500
amostras = pd.DataFrame()
for i in range(total_de_amostras):
  _ = dados.IMC.sample(n)
  _.index = range(0, len(_))
  amostras['Amostra_' + str(i)] = _

amostras
# Out:
#       Amostra_0  Amostra_1  Amostra_2  ...  Amostra_1497  Amostra_1498  Amostra_1499
# 0     16.731880  19.965794  24.120909  ...     17.043203     15.423527     23.903769
# 1     28.100309  19.104932  17.331695  ...     22.024082     20.408163     34.369393
# 2     18.775456  27.807548  17.038210  ...     20.316001     18.308518     20.666298
# 3     22.300173  19.836764  26.184153  ...     19.040923     17.818567     24.483720
# 4     18.452297  18.224808  32.594363  ...     23.225833     19.558034     22.677852
# ...         ...        ...        ...  ...           ...           ...           ...
# 1995  18.534110  19.031688  18.916764  ...     16.382693     13.409573     18.666880
# 1996  16.621907  18.752000  19.288073  ...     25.777325     21.527365     21.244646
# 1997  19.155640  18.328317  18.737281  ...     22.437202     18.215067     21.266783
# 1998  20.309245  30.247836  23.745816  ...     19.716314     21.147098     25.545730
# ...

# %% [markdown]
# O Teorema do Limite Central afirma que, **com o aumento do tamanho da amostra, a distribuição das médias amostrais se aproxima de uma distribuição normal** com média igual à média da população e desvio padrão igual ao desvio padrão da variável original dividido pela raiz quadrada do tamanho da amostra. Este fato é assegurado para n maior ou igual a 30.

# %%
amostras.mean().hist(bins=30)

# %% [markdown]
# O Teorema do Limite Central afirma que, com o aumento do tamanho da amostra, a distribuição das médias amostrais se aproxima de uma distribuição normal **com média igual à média da população** e desvio padrão igual ao desvio padrão da variável original dividido pela raiz quadrada do tamanho da amostra. Este fato é assegurado para n maior ou igual a 30.

# %%
dados.IMC.mean()
# Out:
# 20.95825220663186

# %%
amostras.mean().mean()
# Out:
# 20.957627542949332

# %% [markdown]
# O Teorema do Limite Central afirma que, com o aumento do tamanho da amostra, a distribuição das médias amostrais se aproxima de uma distribuição normal com média igual à média da população e **desvio padrão igual ao desvio padrão da variável original dividido pela raiz quadrada do tamanho da amostra**. Este fato é assegurado para n maior ou igual a 30.
#
# # $$\sigma_\bar{x} = \frac{\sigma}{\sqrt{n}}$$

# %%
import numpy as np

desvio_padrao_amostra_aproximado = dados.IMC.std()/np.sqrt(n)
print(desvio_padrao_amostra_aproximado)
# Out:
# 0.09490859583922757

# %%
amostras.mean().std()
# Out:
# 0.09186669840747315
